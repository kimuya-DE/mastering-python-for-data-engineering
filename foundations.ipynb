# %% [markdown]
# ### My PYTHON Learning Journey => **FOUNDATIONS**
#
# # COURSES => via *Coursera Plus*
# ### 🎓 Duke University — Python, Bash and SQL Essentials for Data Engineering
# *Course 1 Python & Pandas for Data Engineering*
# | Module | Title | Status |
# |--------|-------|--------|
# | 1 |  Getting Started with Python  | ✅ Done |
# | 2 |  Essential Python  | ✅ Done |
#
#
# # 🎓 *University of Michigan* — University of Michigan Python for Everybody Specialization
# *Course 1 Getting Started with Python*
# | Status: 🟡 In Progress
#
# | Module | Title | Status |
# |--------|-------|--------|
# | 1 |  Why We Program  | ✅ Done |
# | 1.2 |  Installing Python  | ✅ Done |
# | 2 |  Variables and Expressions  | ✅ Done |
# | 3 |  Conditional Code  | ✅ Done |
# | 4 |  Functions   | ✅ Done |
# | 5 |  Loops and Iteration  | ✅ Done |
#
#
# # 🎓 *IBM* — Data Engineering Professional Certificate
# *Course 2 Python for Data Science, AI & Development*
# | Status: 🟡 In Progress
#
# | Module | Title | Status |
# |--------|-------|--------|
# | 1 |  Python Data Structures  | 🟡 In Progress |
# | 2 |  Python Python Programming Fundamentals  | 🟡 In Progress |
#
# ---
# **Target Completion:**  Friday, 22 May 2026  |

# %%
import pandas as pd

# Create a Pandas DataFrame 
data = {'Name': ['Kyalo', 'Latifa', 'Kimuya'], 
        'Age': [25, 22, 28]}
df = pd.DataFrame(data) 

# Jupyter Notebook - Display the DataFrame`             
print(df)
# Out:
#      Name  Age
# 0   Kyalo   25
# 1  Latifa   22
# 2  Kimuya   28

# %%
# Pandas in virtual environment 

import pandas as pd

# Create DataFrame
data = {'Fruits':['Apples', 'Bananas', 'Lemons', 'Watermelons'],
        'Items':[80,21,15,10]
        }  
purchases = pd.DataFrame(data)

print(purchases)
# Out:
#         Fruits  Items
# 0       Apples     80
# 1      Bananas     21
# 2       Lemons     15
# 3  Watermelons     10

# %%
# Create virtual environment
#python3 -m venv my_env

# Activate virtual environment 
#source my_env/bin/activate  

# Install packages 
#pip install pandas 

# List installed packages
#pip list

# Generate requirements file
#pip freeze > requirements.txt  

# Deactivate environment
#deactivate

# %%
import pandas as pd

# Create a variable pointing to a pandas Series
s = pd.Series([1, 2, 3,16]) 

# Assign a new variable pointing to the sum 
total = s.sum()  

# Update the variable with an expression
total += 10  

# Raise a pandas AttributeError exception
try:
    s.no_such_attribute() 
except AttributeError:
    print("Oops! That attribute doesn't exist")
# Out:
# Oops! That attribute doesn't exist

# %%
import pandas as pd

def analyze_series(s):
    """Analyze pandas Series.
    
    Demonstrates assertions and exception handling.
    """
    
    # Validate inputs
    assert isinstance(s, pd.Series), "Input must be a pandas Series"  

    try:
        # Attempt processing 
        mean = s.mean()  
        median = s.median()

    # Catch errors    
    except Exception as e:   
        # Manually raise exception
        raise ValueError("Error analyzing series") from e  

    # Assert reasonable results       
    assert (mean > 0) & (median > 0), "Mean and median are invalid!"
    
    return mean, median
    
s = pd.Series([1, 2, 3])
analyze_series(s)
# Out:
# (np.float64(2.0), np.float64(2.0))

# %%
# Function with two parameters 
def add_nums(num1, num2):
    sum = num1 + num2
    return sum

# Call function using parameters  
result = add_nums(5, 3)
print(result)

# Function with default parameter
def hello(name="John"):
    print("Hello " + name)

hello() # Uses default name 
hello("Jane") # Overrides default

# Function with code block
def print_lines():
    print("Line 1")
    print("Line 2")
    print("Line 3")
    
print_lines()
# Out:
# 8
# Hello John
# Hello Jane
# Line 1
# Line 2
# Line 3

# %%
# Function decorator that times execution
from time import time

def timer(func):
    # Nested wrapper function
    def wrapper():
        start = time()
        func()
        end = time()
        print(f"Duration: {end-start}")
    return wrapper

@timer
def sum_nums():
    result = 0
    for x in range(1000000):
        result += x

sum_nums()
# Out:
# Duration: 0.11266732215881348

# %% [markdown]
# ## Compound Statements

# %%
print( 1 == 'b' )
print( 1 != 2 )
print( 1 == 1.0 )
print( 1 == '1' )
print( 1 != 2 )
# Out:
# False
# True
# True
# False
# True

# %%
print( 1 < 33 )
print( 2 >= 2 )
print( 3.0 > 0 )
print( 'z' >= 'a' )
print( 1 <= 1.0 < 4 )
# Out:
# True
# True
# True
# True
# True

# %%
#The comparison operators 
print( 1 is None )
print( True is not None )
# Out:
# False
# True
# <>:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_21182/1820737873.py:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print( 1 is None )

# %%
#Membership Operations
print('e' in 'Henry' )
print('a' not in 'Henry' )
# Out:
# True
# True

# %%
#Boolean operations
print( True and False )
print( True and True )
print( False and True )
print( not True )
print( (False and False) or (not False) )
# Out:
# False
# True
# False
# False
# True

# %%
#Object Evaluations
#Generally, most Python objects evaluate as True. The exceptions are:

    #Numeric types that equal zero, such as 0, or 0.0.

    #The constants False and None.

    #Anything that has a length of zero. This includes the empty string, "".

print( 0 or 'a' )
print( 0 and 0.0 )
# Out:
# a
# 0

# %% [markdown]
# ## if-Statements

# %%
#Basic Syntax
if False:
    print("In the block")
print("Outside the block")
# Out:
# Outside the block

# %%
#Else Syntax
score=45
if score>3:
    print('You win!')
else:
    print('Try again!')
# Out:
# You win!

# %%
#Nested If-Else Syntax
count=70
if count > 5:
    print('Greater than 5')
else:
    if count <5:
        print('Not greater than 5')
# Out:
# Greater than 5

# %%
# elif Syntax
count=2
if count > 5:
    print('Greater than 5') 
elif count == 3:
    print('Equal to 3')
else:
    print('Neither 3 nor 5')
# Out:
# Neither 3 nor 5

# %%
#Match Statements
temp=32
match temp:
    case 33:
        print("Too low")
    case 40:
        print("Too high")
    case _:
        print("Not 33 or 40")
# Out:
# Not 33 or 40

# %%
#Variables in Match Statements
pos=(15,33)
match pos:
    
    case (12,y):
        print(y)
    case (x,33):
        print(x)
    case _:
        print("No match")
# Out:
# 15

# %%
if True:
    print("Hello")
# Out:
# Hello

# %%
if 0 == 1:
    a = 0
    print(a)
else:
    a = 1
    print(a)
# Out:
# 1

# %%
a = 5

if 0 >= a > -1:
    print("Hello")
elif 0 or a:
    print("Goodbye")
else:
    print("What?")
# Out:
# Goodbye

# %%
#Object Evaluations are true except for the special cases
if "":
    print("Ice Cream!")
elif 0.0:
    print("Bananas!")
elif "0":
    print("Sushi!")
else:
    print("Curry!")
# Out:
# Sushi!

# %%
x=32

if x<13:
    a=13
    print(a)
else:
    a=14
    print(a)
# Out:
# 14

# %% [markdown]
# ## While-loops

# %%
#Basic Syntax
count=0
while count<5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#Break Statement
count=0
while count<5:
    print(count)
    count += 1
    if count == 3:
        break
# Out:
# 0
# 1
# 2

# %%
a = 0

while a <= 4:
    print(a)
    a += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a = 0

while a < 4:
    a += 1
    print(a)
else:
    a = 0
    print(a)
# Out:
# 1
# 2
# 3
# 4
# 0

# %% [markdown]
# ## Functions

# %%
#Basic Syntax
def my_tune():
    print("La la la")
    
my_tune()
# Out:
# La la la

# %%
#Pass Statement
def do_nothing():
    pass    

do_nothing()== None
# Out:
# True

# %%
#Return Statement
def ret_two():
    return 2

ret_two()
# Out:
# 2

# %%
def my_func(first, second, third):
    return first, second, third

#my_func(1, 5, 3)
my_func(8, second=5, third=3)
# Out:
# (8, 5, 3)

# %%
#Default Parameters
def greet(name="Kimuya"):
    print(f"Hello, {name}!")
    
greet() # Uses default name
greet("Latti") # Overrides default
# Out:
# Hello, Kimuya!
# Hello, Latti!

# %%
# Function decorator that times execution
from time import time

def timer(func):
    # Nested wrapper function
    def wrapper():
        start = time()
        func()
        end = time()
        print(f"Duration: {end-start}")
    return wrapper

# %%
@timer
def sum_nums():
    result = 0
    for x in range(1000000):
        result += x

sum_nums()
# Out:
# Duration: 0.10090351104736328

# %%
def logger(func):
    def wrapper(*args, **kwargs):
        print(f"Ran {func.__name__} with args: {args}, and kwargs: {kwargs}")
        return func(*args, **kwargs)
    return wrapper

# %%
@logger
def add(x, y):
    return x + y

@logger
def sub(x, y):
    return x - y

add(10, 20)
sub(30, 20)
# Out:
# Ran add with args: (10, 20), and kwargs: {}
# Ran sub with args: (30, 20), and kwargs: {}
# 10

# %%
import functools

def cache(func):
    cache_data = {}
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        key = args + tuple(kwargs.items())
        if key not in cache_data:
            cache_data[key] = func(*args, **kwargs)
        return cache_data[key]
    return wrapper

# %%
import time
@cache
def expensive_func(x):
    start_time = time.time()
    time.sleep(2)
    print(f"{expensive_func.__name__} ran in {time.time() - start_time:.2f} secs")
    return x

# %%
# %time print(expensive_func(1))
# Out:
# expensive_func ran in 2.00 secs
# 1
# CPU times: user 871 μs, sys: 47 μs, total: 918 μs
# Wall time: 2 s

# %%
# %time print(expensive_func(1))
# Out:
# 1
# CPU times: user 161 μs, sys: 10 μs, total: 171 μs
# Wall time: 163 μs

# %%
@cache
def fibonacci(n):
    if n < 2:
        return n
    else:
        return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(10)
# Out:
# 55

# %%
import time
from functools import wraps

def delay(seconds):
    def inner(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            print(f"Sleeping for {seconds} seconds before running {func.__name__}")
            time.sleep(seconds)
            return func(*args, **kwargs)
        return wrapper
    return inner

# %%
@delay(seconds=3)
def print_text():
    print("Hello World")

print_text()
# Out:
# Sleeping for 3 seconds before running print_text
# Hello World

# %%
# Function to calculate simple interest 
def simple_interest(principal, rate, time):
    
    # Calculate simple interest
    interest = principal * rate * time
    
    # Return interest 
    return interest

principal = 5000
rate = 0.1 
time = 5

interest = simple_interest(principal, rate, time)
print(interest) # 2500.0
# Out:
# 2500.0

# %%
i = 0
while True:
    x = 9

    if x < 8:
        break
    elif i > 2:
        break
    x = 6
    print(i)
    i = i + 1
# Out:
# 0
# 1
# 2

# %%
x = 1 + 2 * 3 - 8 / 4
print(x)
# Out:
# 5.0

# %%
hrs = input("Enter Hours:")
h = float(hrs)

rte=input("Enter Rate:")
r=float(rte)

if h<=40:
    print(h*r)
    
elif h>40:
    print((h-40)*(r*1.5)+ 40*r)
# Out:
# 498.75

# %%
score = input("Enter Score: ")
iscore = float(score)

if iscore >=0.9:
    print('A')
elif iscore>=0.8:
    print('B')
elif iscore >=0.7:
    print('C')
elif iscore>=0.6:
    print('D')
elif iscore <0.6:
    print('F')
else:
    print('Out of range')
# Out:
# B

# %%
hrs = input("Enter Hours:")
h = float(hrs)

rte=input("Enter Rate:")
r=float(rte)

if h<=40:
    print(h*r)
    
elif h>40:
    print((h-40)*(r*1.5)+ 40*r)
# Out:
# 498.75

# %%
def computepay(hrs, rte):
    if hrs<=40:
        return hrs*rte
    elif hrs>40:
        return ((hrs-40)*(rte*1.5))+(40*rte)
    

hr = input("Enter Hours:")
hrs=float(hr)
rt= input("Enter Rate:")
rte=float(rt)

p = computepay(hrs,rte)

print("Pay", p)
# Out:
# Pay 498.75

# %%
num=0
tot=0.0
while True:
    sval = input("Enter a number: ")
    if sval == "done":
        break
    try:
        fval = float(sval)
    except:
        print("Invalid input")
        continue
    num = num + 1
    #tot = tot + fval

# %% [markdown]
# ## Key Exercise

# %%
largest = None
smallest = None

while True:
    num = input("Enter a number: ")
    if num == "done":
        break
    try:
        itervar = float(num)
    except:
        print("Invalid input")
        continue
    if largest is None or itervar > largest :
        largest = int(itervar)
    elif smallest is None or itervar < smallest:
        smallest = int(itervar)
   
print('Maximum is', largest)
print('Minimum is', smallest)
# Out:
# Invalid input
# Maximum is 10.0
# Minimum is 2.0

# %%
smallest = None
print('Before:', smallest)
for itervar in [3, 41, 12, 9, 74, 15]:
    if smallest is None or itervar < smallest:
        smallest = itervar
    print('Loop:', itervar, smallest)
print('Smallest:', smallest)
# Out:
# Before: None
# Loop: 3 3
# Loop: 41 3
# Loop: 12 3
# Loop: 9 3
# Loop: 74 3
# Loop: 15 3
# Smallest: 3
