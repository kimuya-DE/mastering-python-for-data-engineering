# %% [markdown]
# ### My PYTHON Learning Journey => **FOUNDATIONS**
#
# # COURSES => via *Coursera Plus*
#
# # 🎓 *Duke University* — Python, Bash and SQL Essentials for Data Engineering Specialization
# *Course 1 Python & Pandas for Data Engineering*
# | Status: 🟡 In Progress
#
# | Module | Title | Status |
# |--------|-------|--------|
# | 1 | Getting Started with Python  | 🟡 In Progress |
# | 2 |  Essential Python  | 🟡 In Progress |
#
#
#
# # 🎓 *University of Michigan* — University of Michigan Python for Everybody Specialization
# *Course 1 Getting Started with Python*
# | Status: 🟡 In Progress
#
# | Module | Title | Status |
# |--------|-------|--------|
# | 1 |  Why We Program  | ✅ Done |
# | 1.2 |  Installing Python  | ✅ Done |
# | 2 |  Variables and Expressions  | 🟡 In Progress |
# | 3 |  Conditional Code  | 🟡 In Progress |
# | 4 |  Functions   | 🟡 In Progress |
# | 5 |  Loops and Iteration  | 🟡 In Progress |
#
#
# # 🎓 *IBM* — Data Engineering Professional Certificate
# *Course 2 Python for Data Science, AI & Development*
# | Status: 🟡 In Progress
#
# | Module | Title | Status |
# |--------|-------|--------|
# | 1 |  Python Data Structures  | 🟡 In Progress |
# | 2 |  Python Python Programming Fundamentals  | 🟡 In Progress |
#
# ---
# **Target Completion:**  Tue, 20 May 2026

# %%
import pandas as pd

# Create a Pandas DataFrame 
data = {'Name': ['John', 'Mary', 'Sarah'], 
        'Age': [25, 32, 28]}
df = pd.DataFrame(data) 

# Jupyter Notebook - Display the DataFrame
print(df)
# Out:
#     Name  Age
# 0   John   25
# 1   Mary   32
# 2  Sarah   28

# %%
# Pandas in virtual environment 

import pandas as pd

# Create DataFrame
data = {'Apples': [30], 'Bananas': [21]}  
purchases = pd.DataFrame(data)

print(purchases)
# Out:
#    Apples  Bananas
# 0      30       21

# %%
# Create virtual environment
#python3 -m venv my_env

# Activate virtual environment 
#source my_env/bin/activate  

# Install packages 
#pip install pandas 

# List installed packages
#pip list

# Generate requirements file
#pip freeze > requirements.txt  

# Deactivate environment
#deactivate
